# %%
##### without prediction losss 
import numpy as np
import matplotlib.pyplot as plt

size = 4
name_list = ["1","50","100","200"]
x = np.arange(size)
a = [1.02,1.24,1.24,1.22]
b = [1.03,1.22,1.23,1.21]
c = [1.04,1.53,1.50,1.41]

d = [1.02,1.09,1.09,1.07]

total_width, n = 0.5, 4
width = total_width / n
x = x - (total_width - width) / 2
plt.grid(axis='y', zorder=0, color="#ccc",linewidth=0.5,linestyle='dashed') 
plt.xlabel('Epoch Number')
plt.ylabel('NN Preserving')
plt.bar(x, a,  width=width, label='reference', color="#90C9E6", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + width, d,  width=width, label='target',color="#219EBC", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 2 * width, b, width=width, label='linear',tick_label=name_list,color="#023047",edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 3 * width, c, width=width, label='autoencoder',color="#FB8402",edgecolor="black",linewidth=0.5,zorder=10)
plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

size = 4
name_list = ["1","50","100","200"]
x = np.arange(size)
#### timevis
a = [0.21,0.85,0.89,0.93]
#### tar in ref
d = [0.14,0.52,0.20,0.18]
#### linear
b = [0.24,0.14,0.32,0.33]
##### autoencoder
c = [0.19,0.88,0.94,0.98]


total_width, n = 0.6, 4
width = total_width / n
x = x - (total_width - width) / 2
plt.grid(axis='y', zorder=0, color="#ccc",linewidth=0.5,linestyle='dashed') 
plt.xlabel('Epoch Number')

plt.ylabel('Prediction Preserving Rate')
plt.bar(x, a,  width=width, label='reference', color="#90C9E6", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + width, d,  width=width, label='target',color="#219EBC", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 2 * width, b, width=width, label='linear',tick_label=name_list,color="#023047",edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 3 * width, c, width=width, label='autoencoder',color="#FB8402",edgecolor="black",linewidth=0.5,zorder=10)


plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

size = 4
name_list = ["1","50","100","200"]
x = np.arange(size)
#### timevis
a = [2.79,2.77,2.46,2.31]
#### tar in ref
d = [1.3,1.29,0.78,0.55]
#### linear
b = [2.79,2.79,2.42,2.09]
##### autoencoder
c = [5.3,4.54,3.97,3.89]
ct = [0,0,3.80]


total_width, n = 0.6, 4
width = total_width / n
x = x - (total_width - width) / 2
plt.grid(axis='y', zorder=0, color="#ccc",linewidth=0.5,linestyle='dashed') 
plt.xlabel('Epoch Number')
plt.ylabel('Boundary Neibour Preserving(k=15)')
plt.bar(x, a,  width=width, label='reference', color="#90C9E6", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + width, d,  width=width, label='target',color="#219EBC", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 2 * width, b, width=width, label='linear',tick_label=name_list,color="#023047",edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 3 * width, c, width=width, label='autoencoder',color="#FB8402",edgecolor="black",linewidth=0.5,zorder=10)

plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the first plot
size = 4
name_list = ["1", "50", "100", "200"]
x = np.arange(size)
a = [1.02, 1.24, 1.24, 1.22]
b = [1.03, 1.22, 1.23, 1.21]
c = [1.04, 1.53, 1.50, 1.41]
d = [1.02, 1.09, 1.09, 1.07]

# Create the figure and axes objects
fig, axs = plt.subplots(ncols=3, figsize=(18, 6))

# Set the grid for all subplots
for ax in axs:
    ax.grid(axis='y', zorder=0, color="#ccc", linewidth=0.5, linestyle='dashed')

# Plot the first subplot
axs[0].set_xlabel('Epoch Number')
axs[0].set_ylabel('NN Preserving')
axs[0].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)


# Plot the second subplot
axs[1].set_xlabel('Epoch Number')
axs[1].set_ylabel('Prediction Preserving Rate')
axs[1].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)


# Plot the third subplot
axs[2].set_xlabel('Epoch Number')
axs[2].set_ylabel('Boundary Neighbor Preserving (k=15)')
axs[2].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].legend(loc='lower center')

plt.legend(bbox_to_anchor=(0, -0.1),frameon=False,ncol=4)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the first plot
size = 4
name_list = ["Same", "Dropout", "Noise", "Mutation"]
x = np.arange(size)
a = [1.02, 1.24, 1.24, 1.22]
b = [1.03, 1.22, 1.23, 1.21]
c = [1.04, 1.53, 1.50, 1.41]
d = [1.02, 1.09, 1.09, 1.07]

# Create the figure and axes objects
fig, axs = plt.subplots(ncols=3, figsize=(18, 6))

# Set the grid for all subplots
for ax in axs:
    ax.grid(axis='y', zorder=0, color="#ccc", linewidth=0.5, linestyle='dashed')

# Plot the first subplot
axs[0].set_xlabel('Experiment Setting')
axs[0].set_ylabel('NN Preserving')
axs[0].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[0].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)


# Plot the second subplot
axs[1].set_xlabel('Experiment Setting')
axs[1].set_ylabel('Prediction Preserving Rate')
axs[1].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[1].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)


# Plot the third subplot
axs[2].set_xlabel('Experiment Setting')
axs[2].set_ylabel('Boundary Neighbor Preserving (k=15)')
axs[2].bar(x, a, width=0.2, label='reference', color="#90C9E6", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.2, d, width=0.2, label='target', color="#219EBC", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.4, b, width=0.2, label='linear', tick_label=name_list, color="#023047", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].bar(x + 0.6, c, width=0.2, label='autoencoder', color="#FB8402", edgecolor="black", linewidth=0.5, zorder=10)
axs[2].legend(loc='lower center')

plt.legend(bbox_to_anchor=(0, -0.1),frameon=False,ncol=4)

# %%
import numpy as np
import matplotlib.pyplot as plt

size = 4
name_list = ["Same","Dropout","Noise","Mutation"]
x = np.arange(size)
#### timevis
a = [0.97,0.96,0.91,0.88]

#### ContraVis-preserving
b = [0.98,0.99,0.98,0.95]

#### timevis-flip
c = [0.38,0.75,0.52,0.72]
##### autoencoder
d = [0.62,0.99,0.84,0.76]


total_width, n = 0.6, 4
width = total_width / n
x = x - (total_width - width) / 2
plt.grid(axis='y', zorder=0, color="#ccc",linewidth=0.5,linestyle='dashed') 
plt.xlabel('Epoch Number')

plt.ylabel('Prediction Acc Rate')
plt.bar(x, a,  width=width, label='TimeVis-preserving', color="#90BEE0", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + width, b,  width=width, label='ContraVis-preserving',color="#4B74B2", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 2 * width, c, width=width, label='TimeVis-flip',tick_label=name_list,color="#FFDF92",edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 3 * width, d, width=width, label='ContraVis-flip',color="#FF8C5A",edgecolor="black",linewidth=0.5,zorder=10)


plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

size = 4
name_list = ["Same","Dropout","Noise","Mutation"]
x = np.arange(size)
#### timevis
a = [0.57,0.96,0.91,0.88]

#### ContraVis-preserving
b = [0.99,0.995,0.95,0.98]

#### timevis-flip
c = [0.68,0.69,0.52,0.88]
##### autoencoder
d = [0.995,0.998,0.98,0.989]


total_width, n = 0.6, 4
width = total_width / n
x = x - (total_width - width) / 2
plt.grid(axis='y', zorder=0, color="#ccc",linewidth=0.5,linestyle='dashed') 
plt.xlabel('Epoch Number')

plt.ylabel('Movement Acc Rate')
plt.bar(x, a,  width=width, label='TimeVis-preserving', color="#90BEE0", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + width, b,  width=width, label='ContraVis-preserving',color="#4B74B2", edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 2 * width, c, width=width, label='TimeVis-flip',tick_label=name_list,color="#FFDF92",edgecolor="black",linewidth=0.5,zorder=10)
plt.bar(x + 3 * width, d, width=width, label='ContraVis-flip',color="#FF8C5A",edgecolor="black",linewidth=0.5,zorder=10)


plt.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.show()
