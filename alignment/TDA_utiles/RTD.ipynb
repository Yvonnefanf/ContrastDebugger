# %%
# pip install git+https://github.com/simonzhang00/ripser-plusplus.git
# pip install git+https://github.com/IlyaTrofimov/RTD.git

# %%
import numpy as np
import rtd

# %%
np.random.seed(7)
P = np.random.rand(1000, 3)
Q = np.random.rand(1000, 3)

barc = rtd.calc_embed_dist(P, Q)
rtd.plot_barcodes(rtd.barc2array(barc))
# Out:
# H0: num barcodes 0
# H1: num barcodes 1446
# max0,976Barcode 1 = 0.1546926349401474
# maxBarcode 1 = 0.2090116310864687
# middleBarcode 1 = 0.06612826138734818

# %%
rtd.rtd(P, Q)
# Out:
# 35.294204875640574
